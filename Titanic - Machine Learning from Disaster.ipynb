# %% [markdown]
# # Titanic - Machine Learning from Disaster
# - **ML model created by Marlon Viasus**
# - RandomForestClassifier and GridSearchCV
# - Data obtained from: https://www.kaggle.com/c/titanic/data

# %% [markdown]
# **Importando el dataset**

# %%
import pandas as pd

train_data = pd.read_csv('/data/workspace_files/Titanic - Machine Learning from Disaster/train.csv')
train_data
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PassengerId</th>
#       <th>Survived</th>
#       <th>Pclass</th>
#       <th>Name</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Ticket</th>
#       <th>Fare</th>
#       <th>Cabin</th>
#       <th>Embarked</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>0</td>
#       <td>3</td>
#       <td>Braund, Mr. Owen Harris</td>
#       <td>male</td>
#       <td>22.0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>A/5 21171</td>
#       <td>7.2500</td>
#       <td>NaN</td>
#       <td>S</td>
# ...

# %% [markdown]
# **Train data EDA**

# %% [markdown]
# Se elimina la columna 'Cabin' debido a que hay muchos datos NaN

# %%
train_data.drop(columns='Cabin', inplace=True)
train_data
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PassengerId</th>
#       <th>Survived</th>
#       <th>Pclass</th>
#       <th>Name</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Ticket</th>
#       <th>Fare</th>
#       <th>Embarked</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>0</td>
#       <td>3</td>
#       <td>Braund, Mr. Owen Harris</td>
#       <td>male</td>
#       <td>22.0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>A/5 21171</td>
#       <td>7.2500</td>
#       <td>S</td>
#     </tr>
#     <tr>
#       <th>1</th>
# ...

# %% [markdown]
# Rellenamos los dos valores NaN que existen en la columna 'Embarked' con la opcion que mas se repite que en este caso es 'S'

# %%
train_data.Embarked.fillna('S', inplace=True)
train_data
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PassengerId</th>
#       <th>Survived</th>
#       <th>Pclass</th>
#       <th>Name</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Ticket</th>
#       <th>Fare</th>
#       <th>Embarked</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>0</td>
#       <td>3</td>
#       <td>Braund, Mr. Owen Harris</td>
#       <td>male</td>
#       <td>22.0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>A/5 21171</td>
#       <td>7.2500</td>
#       <td>S</td>
#     </tr>
#     <tr>
#       <th>1</th>
# ...

# %% [markdown]
# Rellenamos los valores NaN en 'Age' con la mediana por clases de 'Pclass'

# %%
age_median_by_class = train_data.groupby('Pclass')['Age'].transform('median')
train_data.Age.fillna(age_median_by_class, inplace=True)
train_data
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PassengerId</th>
#       <th>Survived</th>
#       <th>Pclass</th>
#       <th>Name</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Ticket</th>
#       <th>Fare</th>
#       <th>Embarked</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>0</td>
#       <td>3</td>
#       <td>Braund, Mr. Owen Harris</td>
#       <td>male</td>
#       <td>22.0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>A/5 21171</td>
#       <td>7.2500</td>
#       <td>S</td>
#     </tr>
#     <tr>
#       <th>1</th>
# ...

# %% [markdown]
# Graficamos la columna 'Age' para ver su distribucion

# %%
import seaborn as sns

sns.displot(data=train_data.Age);

# %% [markdown]
# Convertimos las variables 'Sex' y 'Embarked' en dummy

# %%
train_data = pd.get_dummies(train_data, columns=['Sex','Embarked'], drop_first=True)
train_data
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PassengerId</th>
#       <th>Survived</th>
#       <th>Pclass</th>
#       <th>Name</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Ticket</th>
#       <th>Fare</th>
#       <th>Sex_male</th>
#       <th>Embarked_Q</th>
#       <th>Embarked_S</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>0</td>
#       <td>3</td>
#       <td>Braund, Mr. Owen Harris</td>
#       <td>22.0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>A/5 21171</td>
#       <td>7.2500</td>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
# ...

# %% [markdown]
# Eliminamos las columnas 'Name' y 'Ticket' debido a que no aportan informacion relevante para el entrenamiento del modelo

# %%
train_data.drop(columns=['Name','Ticket'],axis=1,inplace=True)
train_data
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PassengerId</th>
#       <th>Survived</th>
#       <th>Pclass</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Fare</th>
#       <th>Sex_male</th>
#       <th>Embarked_Q</th>
#       <th>Embarked_S</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>0</td>
#       <td>3</td>
#       <td>22.0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>7.2500</td>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>1</td>
#       <td>1</td>
# ...

# %% [markdown]
# Vemos que el dataset ha sido debidamente tratado y esta listo para implementarlo al modelo

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Age          891 non-null    float64
#  4   SibSp        891 non-null    int64
#  5   Parch        891 non-null    int64
#  6   Fare         891 non-null    float64
#  7   Sex_male     891 non-null    uint8
#  8   Embarked_Q   891 non-null    uint8
#  9   Embarked_S   891 non-null    uint8
# dtypes: float64(2), int64(5), uint8(3)
# memory usage: 51.5 KB

# %% [markdown]
# # Creacion del modelo de ML

# %% [markdown]
# **Utilizamos RandomForestClassifier y cross validation con GridSearchCV**

# %%
from sklearn.ensemble import RandomForestClassifier

bosque = RandomForestClassifier()
bosque.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %% [markdown]
# Definimos los mejores hiperparametros para la cross validation

# %%
from sklearn.model_selection import GridSearchCV

parametros = {
    'n_estimators': [50, 100, 150],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['sqrt', 'log2'],
    'criterion': ['gini', 'entropy']
}

rejilla = GridSearchCV(bosque, parametros, scoring='accuracy', cv=10)
rejilla.fit(train_data[train_data.columns[2:]].values, train_data['Survived'].values)
# Out:
# <style>#sk-container-id-1 {color: black;background-color: white;}#sk-container-id-1 pre{padding: 0;}#sk-container-id-1 div.sk-toggleable {background-color: white;}#sk-container-id-1 label.sk-toggleable__label {cursor: pointer;display: block;width: 100%;margin-bottom: 0;padding: 0.3em;box-sizing: border-box;text-align: center;}#sk-container-id-1 label.sk-toggleable__label-arrow:before {content: "▸";float: left;margin-right: 0.25em;color: #696969;}#sk-container-id-1 label.sk-toggleable__label-arrow:hover:before {color: black;}#sk-container-id-1 div.sk-estimator:hover label.sk-toggleable__label-arrow:before {color: black;}#sk-container-id-1 div.sk-toggleable__content {max-height: 0;max-width: 0;overflow: hidden;text-align: left;background-color: #f0f8ff;}#sk-container-id-1 div.sk-toggleable__content pre {margin: 0.2em;color: black;border-radius: 0.25em;background-color: #f0f8ff;}#sk-container-id-1 input.sk-toggleable__control:checked~div.sk-toggleable__content {max-height: 200px;max-wid
# ...

# %% [markdown]
# Imprimimos el mejor resultado y los mejores hiperparametros

# %%
print(rejilla.best_score_)
print(rejilla.best_params_)
# Out:
# 0.8417852684144819
# {'criterion': 'entropy', 'max_depth': 30, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 150}

# %% [markdown]
# # Preparamos nuestro dataset de Test

# %% [markdown]
# **Test data EDA**

# %% [markdown]
# Realizamos el mismo procedimiento que con el dataset de train

# %%
import pandas as pd

test_data = pd.read_csv('/data/workspace_files/Titanic - Machine Learning from Disaster/test.csv')
test_data
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PassengerId</th>
#       <th>Pclass</th>
#       <th>Name</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Ticket</th>
#       <th>Fare</th>
#       <th>Cabin</th>
#       <th>Embarked</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>892</td>
#       <td>3</td>
#       <td>Kelly, Mr. James</td>
#       <td>male</td>
#       <td>34.5</td>
#       <td>0</td>
#       <td>0</td>
#       <td>330911</td>
#       <td>7.8292</td>
#       <td>NaN</td>
#       <td>Q</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>893</td>
# ...

# %%
test_data.drop(columns=['Name','Cabin','Ticket'], inplace=True)
test_data
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PassengerId</th>
#       <th>Pclass</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Fare</th>
#       <th>Embarked</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>892</td>
#       <td>3</td>
#       <td>male</td>
#       <td>34.5</td>
#       <td>0</td>
#       <td>0</td>
#       <td>7.8292</td>
#       <td>Q</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>893</td>
#       <td>3</td>
#       <td>female</td>
#       <td>47.0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>7.0000</td>
#       <td>S</td>
# ...

# %%
test_data.Fare.fillna(test_data.Fare.mean(), inplace=True)
test_data
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PassengerId</th>
#       <th>Pclass</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Fare</th>
#       <th>Embarked</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>892</td>
#       <td>3</td>
#       <td>male</td>
#       <td>34.5</td>
#       <td>0</td>
#       <td>0</td>
#       <td>7.8292</td>
#       <td>Q</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>893</td>
#       <td>3</td>
#       <td>female</td>
#       <td>47.0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>7.0000</td>
#       <td>S</td>
# ...

# %%
age_median_by_class = test_data.groupby('Pclass')['Age'].transform('median')
test_data.Age.fillna(age_median_by_class, inplace=True)
test_data
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PassengerId</th>
#       <th>Pclass</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Fare</th>
#       <th>Embarked</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>892</td>
#       <td>3</td>
#       <td>male</td>
#       <td>34.5</td>
#       <td>0</td>
#       <td>0</td>
#       <td>7.8292</td>
#       <td>Q</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>893</td>
#       <td>3</td>
#       <td>female</td>
#       <td>47.0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>7.0000</td>
#       <td>S</td>
# ...

# %%
test_data = pd.get_dummies(test_data, columns=['Sex', 'Embarked'], drop_first=True)
test_data
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PassengerId</th>
#       <th>Pclass</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Fare</th>
#       <th>Sex_male</th>
#       <th>Embarked_Q</th>
#       <th>Embarked_S</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>892</td>
#       <td>3</td>
#       <td>34.5</td>
#       <td>0</td>
#       <td>0</td>
#       <td>7.8292</td>
#       <td>1</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>893</td>
#       <td>3</td>
#       <td>47.0</td>
#       <td>1</td>
#       <td>0</td>
# ...

# %% [markdown]
# # Testeamos nuestro modelo con el mejor estimador

# %% [markdown]
# Definimos el mejor estimador y lo evaluamos con el dataset de test

# %%
mejor_estimador = rejilla.best_estimator_

predictions = mejor_estimador.predict(test_data.iloc[:, 1:])

resultados = pd.DataFrame({'PassengerId': test_data['PassengerId'], 'Survived': predictions})

resultados.to_csv('results.csv', index=False)
# Out:
# /opt/python/envs/default/lib/python3.8/site-packages/sklearn/base.py:432: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(

# %% [markdown]
# **Guardamos nuestros resultados obtenidos en un archivo .csv**

# %%
results = pd.read_csv('results.csv')
results
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PassengerId</th>
#       <th>Survived</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>892</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>893</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>894</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>895</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>896</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>413</th>
# ...
